# %% [markdown]
# # MATPLOTLIB

# %% [markdown]
# ### It is one of the popular packages used for data visualisation.
# ### It is a cross-platform library for making 2D plots from data in arrays.
# ### It is written in python and makes use of numpy of python.
# ### It provides an object-oriented API.

# %%
from matplotlib import pyplot as plt 
import numpy as np 
import math #needed for definition of pi
x = np.arange(0, math.pi*2, 0.05) #0.05 means interval between two numbers
y = np.sin(x) 
plt.plot(x,y) 
plt.xlabel("angle") 
plt.ylabel("sine") 
plt.title('sine wave') 
plt.show()

# %% [markdown]
# ### Basic plotting:

# %% [markdown]
# .Plotting curves is done with the help of plot command.
#
# .It takes a pair of same length arrays and sequences.

# %%
from matplotlib import pyplot as plt 
from numpy import * 
from pylab import * 
x = linspace(-3, 3, 30) 
y = x**2 
plot(x, y) 
show()

# %% [markdown]
# .To plot symbols other than lines,provide an additional string argument.
#
# .Symbols - - , –, -., , . , , , o , ^ , v , < , > , s , + , x , D , d , 1 , 2 , 3 , 4 , h , H , p , | , _
#
# .Colors - b, g, r, c, m, y, k, w

# %%
from pylab import * 
x = linspace(-3, 3, 30) 
y = x**2 
plot(x, y, 'r.') # r means red, . means dotted lines
show()

# %%
from pylab import *
X = linspace(-3,3,30)
plot(x, sin(x)) 
plot(x, cos(x), 'r-') 
plot(x, -sin(x), 'g--') 
show()

# %%
from matplotlib import pyplot as plt 
import numpy as np 
import math 
x = np.arange(0, math.pi*2, 0.05) 
y = np.sin(x)
fig = plt.figure() 
ax = fig.add_axes([0,0,1,1]) 
ax.plot(x,y)
ax.set_title("sine wave") 
ax.set_xlabel('angle') 
ax.set_ylabel('sine') 
plt.show()

# %%
import matplotlib.pyplot as plt 
y = [1, 4, 9, 16, 25,36,49, 64] 
x1 = [1, 16, 30, 42,55, 68, 77,88] 
x2 = [1,6,12,18,28, 40, 52, 65] 
fig = plt.figure() 
ax = fig.add_axes([0,0,1,1]) 
l1 = ax.plot(x1,y,'ys-') # solid line with yellow colour and square marker
l2 = ax.plot(x2,y,'go--') # dash line with green colour and circle marker 
ax.legend(labels = ('tv', 'Smartphone'), loc = 'lower right') # legend placed at lower right ax.set_title("Advertisement effect on sales") ax.set_xlabel('medium') 
ax.set_ylabel('sales') 
plt.show()
